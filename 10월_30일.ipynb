# %% [markdown]
# <a href="https://colab.research.google.com/github/mskang222/NLP_2023/blob/main/10%EC%9B%94_30%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# knn연습

# %%
#라이브러리 임포트
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 그래프 출력을 위해 선언합니다.
# %matplotlib inline
# sklearn 모델의 동일한 결과 출력을 위해 선언합니다.
np.random.seed(5)

# %%
#데이터 불러오기 (학습 데이터, 테스트 데이터)
df= pd.read_csv("https://raw.githubusercontent.com/wikibook/machine-learning/2.0/data/csv/basketball_stat.csv")
df.head(3)
# Out:
#           Player Pos   3P   2P  TRB  AST  STL  BLK
# 0   Alex Abrines  SG  1.4  0.6  1.3  0.6  0.5  0.1
# 1   Steven Adams   C  0.0  4.7  7.7  1.1  1.1  1.0
# 2  Alexis Ajinca   C  0.0  2.3  4.5  0.3  0.5  0.6

# %%
df
# Out:
#               Player Pos   3P   2P   TRB  AST  STL  BLK
# 0       Alex Abrines  SG  1.4  0.6   1.3  0.6  0.5  0.1
# 1       Steven Adams   C  0.0  4.7   7.7  1.1  1.1  1.0
# 2      Alexis Ajinca   C  0.0  2.3   4.5  0.3  0.5  0.6
# 3     Chris Andersen   C  0.0  0.8   2.6  0.4  0.4  0.6
# 4        Will Barton  SG  1.5  3.5   4.3  3.4  0.8  0.5
# ..               ...  ..  ...  ...   ...  ...  ...  ...
# 95    Nikola Vucevic   C  0.3  6.1  10.4  2.8  1.0  1.0
# 96       Dwyane Wade  SG  0.8  6.2   4.5  3.8  1.4  0.7
# 97      Dion Waiters  SG  1.8  4.3   3.3  4.3  0.9  0.4
# 98  Hassan Whiteside   C  0.0  7.0  14.1  0.7  0.7  2.1
# 99      Lou Williams  SG  2.0  3.3   2.5  3.0  1.0  0.2
#
# [100 rows x 8 columns]

# %%
#sklearn의 train_test_split을 사용하면 라인 한줄로 손쉽게 데이터를 나눌 수 있다.
from sklearn.model_selection import train_test_split

#다듬어진 데이터에서 20%를 테스트 데이터로 분류합니다.
train_6, test_6= train_test_split(df,test_size=0.2,random_state=99)  #traning:test=8:2

print(train_6.shape,test_6.shape)
# Out:
# (80, 8) (20, 8)

# %%
train_6   #random_state에 의해서 번호가 무작위로 배정
# Out:
#               Player Pos   3P   2P   TRB  AST  STL  BLK
# 97      Dion Waiters  SG  1.8  4.3   3.3  4.3  0.9  0.4
# 4        Will Barton  SG  1.5  3.5   4.3  3.4  0.8  0.5
# 45       Buddy Hield  SG  1.8  2.2   3.3  1.5  0.5  0.1
# 54    Frank Kaminsky   C  1.5  2.7   4.5  2.2  0.6  0.5
# 25    Andre Drummond   C  0.0  5.9  13.8  1.1  1.5  1.1
# ..               ...  ..  ...  ...   ...  ...  ...  ...
# 73    Victor Oladipo  SG  1.9  4.3   4.3  2.6  1.2  0.3
# 40  Montrezl Harrell   C  0.0  3.9   3.8  1.1  0.3  0.7
# 57      Kosta Koufos   C  0.0  3.0   5.7  0.7  0.5  0.7
# 35     Marcin Gortat   C  0.0  4.8  10.4  1.5  0.5  0.7
# 1       Steven Adams   C  0.0  4.7   7.7  1.1  1.1  1.0
#
# [80 rows x 8 columns]

# %%
test_6
# Out:
#                       Player Pos   3P   2P   TRB  AST  STL  BLK
# 14  Kentavious Caldwell-Pope  SG  2.0  2.9   3.3  2.5  1.2  0.2
# 34               Eric Gordon  SG  3.3  2.2   2.7  2.5  0.6  0.5
# 30                Marc Gasol   C  1.4  5.8   6.3  4.6  0.9  1.3
# 78           Josh Richardson  SG  1.4  2.4   3.2  2.6  1.1  0.7
# 16       Willie Cauley-Stein   C  0.0  3.4   4.5  1.1  0.7  0.6
# 15              Clint Capela   C  0.0  5.6   8.1  1.0  0.5  1.2
# 91        Karl-Anthony Towns   C  1.2  8.5  12.3  2.7  0.7  1.3
# 38              A.J. Hammons   C  0.2  0.5   1.6  0.2  0.0  0.6
# 10               Tarik Black   C  0.0  2.2   5.1  0.6  0.4  0.7
# 85         Marreese Speights   C  1.3  1.7   4.5  0.8  0.3  0.5
# 79             Austin Rivers  SG  1.5  2.9   2.2  2.8  0.6  0.1
# 71            Timofey Mozgov   C  0.0  3.1   4.9  0.8  0.3  0.6
# 6               Bradley Beal  SG  2.9  5.4   3.1  3.5  1.1  0.3
# 7            Marco Belinelli  SG  1.4  2.2   2.4  2.0  0.6  0.1
# ...

# %%
train_3 = pd.read_csv("https://raw.githubusercontent.com/wikibook/machine-learning/2.0/data/csv/basketball_train.csv")
test_3 = pd.read_csv("https://raw.githubusercontent.com/wikibook/machine-learning/2.0/data/csv/basketball_test.csv")

# %%
train_3
# Out:
#                  Player Pos   3P  TRB  BLK
# 0      Denzel Valentine  SG  1.3  2.6  0.1
# 1           Kyle Korver  SG  2.4  2.8  0.3
# 2          Troy Daniels  SG  2.1  1.5  0.1
# 3          Tim Hardaway  SG  1.9  2.8  0.2
# 4        Dewayne Dedmon   C  0.0  6.5  0.8
# ..                  ...  ..  ...  ...  ...
# 75       Victor Oladipo  SG  1.9  4.3  0.3
# 76  Willie Cauley-Stein   C  0.0  4.5  0.6
# 77          Brook Lopez   C  1.8  5.4  1.7
# 78      Josh Richardson  SG  1.4  3.2  0.7
# 79         Lou Williams  SG  2.0  2.5  0.2
#
# [80 rows x 5 columns]

# %%
test_3
# Out:
#                   Player Pos   3P   TRB  BLK
# 0           JaVale McGee   C  0.0   3.2  0.9
# 1          Manu Ginobili  SG  1.3   2.3  0.2
# 2           Nene Hilario   C  0.0   4.2  0.6
# 3          Evan Fournier  SG  1.9   3.1  0.1
# 4   Georgios Papagiannis   C  0.0   3.9  0.8
# 5          Anthony Davis   C  0.5  11.8  2.2
# 6            Tarik Black   C  0.0   5.1  0.7
# 7         Jamal Crawford  SG  1.4   1.6  0.2
# 8        Jordan Clarkson  SG  1.4   3.0  0.1
# 9          Marcin Gortat   C  0.0  10.4  0.7
# 10          Dion Waiters  SG  1.8   3.3  0.4
# 11       Justin Hamilton   C  0.9   4.1  0.7
# 12         E'Twaun Moore  SG  1.1   2.1  0.4
# 13      Montrezl Harrell   C  0.0   3.8  0.7
# 14              Alex Len   C  0.0   6.6  1.3
# 15           Eric Gordon  SG  3.3   2.7  0.5
# 16            Joe Harris  SG  1.6   2.8  0.2
# 17          Kosta Koufos   C  0.0   5.7  0.7
# 18          Devin Booker  SG  1.9   3.2  0.3
# 19           Salah Mejri   C  0.0   4.2  0.8

# %%
#train_3: 3개의 칼럼으로 이루어져야 된다.(운동선수 이름, 포지션)
x_train_3=train_3[['3P','TRB','BLK']] #학습할때 사용할 문제
y_train_3=train_3[['Pos']]    #학습할때 사용할 답

# %%
x_train_3  #문제지
# Out:
#      3P  TRB  BLK
# 0   1.3  2.6  0.1
# 1   2.4  2.8  0.3
# 2   2.1  1.5  0.1
# 3   1.9  2.8  0.2
# 4   0.0  6.5  0.8
# ..  ...  ...  ...
# 75  1.9  4.3  0.3
# 76  0.0  4.5  0.6
# 77  1.8  5.4  1.7
# 78  1.4  3.2  0.7
# 79  2.0  2.5  0.2
#
# [80 rows x 3 columns]

# %%
y_train_3  #답안지
# Out:
#    Pos
# 0   SG
# 1   SG
# 2   SG
# 3   SG
# 4    C
# ..  ..
# 75  SG
# 76   C
# 77   C
# 78  SG
# 79  SG
#
# [80 rows x 1 columns]
