# %% [markdown]
# <a href="https://colab.research.google.com/github/mskang222/NLP_2023/blob/main/12%EC%9B%94_18%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#다층퍼셉트론 XOR
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# 항상 같은 결과를 갖기 위해 랜덤 시드 설정
tf.random.set_seed(678)

import numpy as np
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
X = np.array([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = np.array([0.,1.,1.,0.])

# %%
model = Sequential()
# 첫번째 히든 레이어
model.add(Dense(units=2,activation='sigmoid',input_dim=2))
# 두번째 히든 레이어
model.add(Dense(units=1,activation='sigmoid'))

# %%
# 손실 함수 및 최적화 정의
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %%
# 모델 요약
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.fit(X,y,epochs=500,batch_size=4,verbose=1)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5460 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5460 - accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5459 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5458 - accuracy: 0.7500
# Epoch 10/500
# ...

# %%
print(model.predict(X,batch_size=4))
# Out:
# 1/1 [==============================] - 0s 81ms/step
# [[0.22900036]
#  [0.60572785]
#  [0.5976456 ]
#  [0.58183926]]

# %%
#첫번째 파라미터
print("first layer weights: ",model.layers[0].get_weights()[0])
print("first layer bias: ",model.layers[0].get_weights()[1])

# %%
#두번째 파라미터
print("second layer weights: ",model.layers[1].get_weights()[0])
print("second layer bias: ",model.layers[1].get_weights()[1])
# Out:
# second layer weights:  [[ 1.4341186]
#  [-3.5131967]]
# second layer bias:  [-0.09305685]
